# %% [markdown]
# <a href="https://colab.research.google.com/github/blissfulcat/COMP250-A3-Tester/blob/master/MLassignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
NHANES_df = pd.read_csv("/content/gdrive/MyDrive/ML2024/national+health+and+nutrition+health+survey+2013-2014+(nhanes)+age+prediction+subset/NHANES_age_prediction.csv", index_col=0)
NHANES_df
# Out:
#         age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  \
# SEQN
# 73564.0     Adult      61.0       2.0     2.0    35.7   110.0     2.0   150.0
# 73568.0     Adult      26.0       2.0     2.0    20.3    89.0     2.0    80.0
# 73576.0     Adult      16.0       1.0     2.0    23.2    89.0     2.0    68.0
# 73577.0     Adult      32.0       1.0     2.0    28.9   104.0     2.0    84.0
# 73580.0     Adult      38.0       2.0     1.0    35.9   103.0     2.0    81.0
# ...           ...       ...       ...     ...     ...     ...     ...     ...
# 83711.0     Adult      38.0       2.0     2.0    33.5   100.0     2.0    73.0
# 83712.0     Adult      61.0       1.0     2.0    30.0    93.0     2.0   208.0
# 83713.0     Adult      34.0       1.0     2.0    23.7   103.0     2.0   124.0
# 83718.0     Adult      60.0       2.0     2.0    27.4    90.0     2.0   108.0
# 83727.0     Adult      26.0       1.0     2.0    24.5   108.0     2.0   108.0
#
#          LBXIN
# SEQN
# ...

# %%
BCW_df = pd.read_csv("/content/gdrive/MyDrive/ML2024/breast+cancer+wisconsin+original/wdbc.data", index_col=0)
BCW_df
# Out:
#           M  17.99  10.38   122.8    1001   0.1184   0.2776   0.3001   0.1471  \
# 842302
# 842517    M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# 843786    M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780  0.08089
# ...      ..    ...    ...     ...     ...      ...      ...      ...      ...
# 926424    M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 926682    M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 926954    M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 927241    M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 92751     B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
# ...

# %%
NHANES_df.info()
print("Number of NANs is", NHANES_df.isna().sum().sum())
print("Shape is ", NHANES_df.shape)
NHANES_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2278 entries, 73564.0 to 83727.0
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age_group  2278 non-null   object
#  1   RIDAGEYR   2278 non-null   float64
#  2   RIAGENDR   2278 non-null   float64
#  3   PAQ605     2278 non-null   float64
#  4   BMXBMI     2278 non-null   float64
#  5   LBXGLU     2278 non-null   float64
#  6   DIQ010     2278 non-null   float64
#  7   LBXGLT     2278 non-null   float64
#  8   LBXIN      2278 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 178.0+ KB
# Number of NANs is 0
# Shape is  (2278, 9)
#           RIDAGEYR     RIAGENDR       PAQ605       BMXBMI       LBXGLU  \
# count  2278.000000  2278.000000  2278.000000  2278.000000  2278.000000
# mean     41.795874     1.511414     1.822651    27.955180    99.553117
# std      20.156111     0.499979     0.398918     7.248962    17.889834
# ...

# %%
BCW_df.info()
print("Number of NANs is", BCW_df.isna().sum().sum())
print("Shape is ", BCW_df.shape)
BCW_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 698 entries, 1002945 to 897471
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   5       698 non-null    int64
#  1   1       698 non-null    int64
#  2   1.1     698 non-null    int64
#  3   1.2     698 non-null    int64
#  4   2       698 non-null    int64
#  5   1.3     698 non-null    object
#  6   3       698 non-null    int64
#  7   1.4     698 non-null    int64
#  8   1.5     698 non-null    int64
#  9   2.1     698 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 60.0+ KB
# Number of NANs is 0
# Shape is  (698, 10)
#                 5           1         1.1         1.2           2           3  \
# count  698.000000  698.000000  698.000000  698.000000  698.000000  698.000000
# mean     4.416905    3.137536    3.210602    2.809456    3.217765    3.438395
# std      2.817673    3.052575    2.972867    2.856606    2.215408    2.440056
# ...
